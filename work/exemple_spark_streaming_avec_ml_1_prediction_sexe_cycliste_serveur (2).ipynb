# %% [markdown]
# # -1) imports

# %%
import socket
import random
import time

# %%
port = 12010
ip   = socket.gethostname()

# %%
try    : serversocket.shutdown(socket.SHUT_RDWR); print ("shutdowned")
except : pass
try    : serversocket.close(); print ("closed")
except : pass

# %%
serversocket = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
serversocket.bind((ip, port))
serversocket.listen(1)

# %%
(clientsocket, address) = serversocket.accept()

# %%
cyclistes = [[0,15,3.00762748585,27.6106079882,0.5],
[6,25,7.34991951874,23.0506752616,0.5],
[-0.5,74,3.60299948446,15.3381626814,0.5],
[-0.5,46,7.67910017225,15.6115041601,0.5],
[4,61,11.987793618,12.539226094,0.5],
[4,41,1.44260055802,17.1301514644,0.5],
[4,41,6.0905231915,19.3929684602,0.5],
[6,54,12.3071491418,19.2549001349,0.5],
[6,50,-2.35942808858,23.3595736977,0.5],
[0,23,-0.161580375364,27.0571082878,0.5],
[0,60,8.15844083358,13.1507195909,0.5],
[4,61,11.5281460003,19.3081006665,0.5],
[0,20,11.0689073734,23.7423638213,0.5],
[0,49,2.47601229919,21.512356108,0.5],
[6,20,9.62245193285,20.7642657323,0.5],
[2,67,5.17714344282,14.240872812,0.5],
[2,52,14.4993233319,7.1012586083,0.5],
[-0.5,22,7.49048452957,28.455947183,0.5],
[6,64,10.6083809521,25.6323316098,0.5],
[6,77,8.44023081332,26.2667348532,0.5],
[-0.5,57,7.00560687935,8.05391839165,0.5],
[-0.5,64,8.52279304142,14.9142539665,0.5],
[6,69,11.5656738823,19.221761514,0.5],
[0,80,11.5174590946,9.28826416801,0.5],
[2,77,10.7456960142,9.33324148979,0.5],
[4,18,6.18127660497,21.9089376284,0.5],
[0,25,10.2491355484,25.307120538,0.5],
[0,64,5.64679356165,15.0766903563,0.5],
[0,58,16.845896546,12.4061308564,0.5],
[-0.5,50,3.33616122093,14.4580584854,0.5],
[6,40,12.4115305575,22.5050492332,0.5],
[0,69,8.1152571411,10.7165050282,0.5],
[0,45,12.6380973246,13.8567289471,0.5],
[-0.5,69,12.661823232,20.5536216275,0.5],
[6,46,8.01743218349,34.2498526953,0.5],
[0,58,8.42373054903,12.6812004071,0.5],
[0,74,9.95673972282,12.8898997364,0.5],
[6,49,11.2048663726,25.2942437208,0.5],
[2,55,1.79776584396,14.6123855101,0.5],
[6,19,15.1554168438,26.2756598673,0.5],
[0,19,19.5106804081,20.3828509543,0.5],
[2,34,12.118577839,22.3795438224,0.5],
[6,58,15.1511820074,17.042895374,0.5],
[6,51,12.2580057218,16.5550289643,0.5],
[6,42,2.47219429383,21.3365801536,0.5],
[2,19,4.90685680133,22.1244000501,0.5],
[2,71,6.88507023963,15.3503813511,0.5],
[2,59,9.0315878587,15.5626550751,0.5],
[6,46,0.739979650358,31.3921986613,0.5],
[-0.5,72,17.9096470126,12.0526259974,0.5],
[0,78,1.78680111859,21.3208450333,0.5],
[2,41,13.1161713533,16.6396569333,0.5],
[6,19,5.12606879189,28.5013359252,0.5],
[0,51,10.987149998,7.03932069938,0.5],
[0,38,11.9751058918,19.4484836325,0.5],
[6,22,9.38216508416,26.0128991899,0.5],
[-0.5,75,0.223663774554,16.2525480098,0.5],
[6,52,8.87812433346,19.2977899521,0.5],
[4,51,13.0282151074,18.7025003391,0.5],
[2,20,7.90241597117,31.9790107439,0.5],
[-0.5,18,11.616031467,22.9913940357,0.5],
[6,33,7.9642406476,28.1602933491,0.5],
[4,38,4.04819616285,21.7009289685,0.5],
[2,21,7.03117172514,27.341029578,0.5],
[2,21,11.665794991,21.2792014511,0.5],
[0,53,4.49938422852,15.826077878,0.5],
[6,58,10.0241197754,21.2757806317,0.5],
[4,42,11.7358829972,14.5031669661,0.5],
[-0.5,47,4.8750903629,17.1267127028,0.5],
[6,48,8.69231748783,19.0508129004,0.5],
[2,15,-1.5172154272,29.697053071,0.5],
[6,50,9.32580031188,14.4217345995,0.5],
[6,39,4.7689443956,22.4348639948,0.5],
[4,79,8.38151603143,21.8602237028,0.5],
[6,59,7.10896374275,18.6097479153,0.5],
[4,78,16.6476010232,10.0230570031,0.5],
[-0.5,48,11.7697677653,11.7833288758,0.5],
[6,73,8.52107100559,18.0575124276,0.5],
[-0.5,26,3.17468791525,24.2648999488,0.5],
[0,45,2.38444122465,17.5155980846,0.5],
[2,23,8.48742951076,27.4169106632,0.5],
[6,70,19.0837232817,15.4156656,0.5],
[4,24,9.0125870513,22.2147585682,0.5],
[2,68,8.99552745306,9.90146112514,0.5],
[-0.5,45,9.15198122665,18.8817543924,0.5],
[0,51,3.50252867312,15.5252802259,0.5],
[4,38,5.73866571904,23.5402980179,0.5],
[4,23,1.40029302281,27.6507250273,0.5],
[6,54,14.3583185682,14.1456860876,0.5],
[6,17,6.42476289785,26.2643728791,0.5],
[4,79,3.98364016186,13.253765137,0.5],
[2,53,2.44223966522,18.4870271945,0.5],
[4,29,5.42015690862,21.1501580983,0.5],
[4,23,11.2265104712,22.5387369459,0.5],
[0,25,11.1781830741,24.302725896,0.5],
[0,31,4.07520943564,15.7465957053,0.5],
[-0.5,30,7.77948102202,25.5325456855,0.5],
[6,37,9.93518307039,17.5182146409,0.5],
[6,62,10.3452195521,16.4120852711,0.5],
[2,45,9.9665713889,18.8716371884,0.5],
[4,22,10.4403368799,25.5328814411,0.5],
[0,63,14.7538977883,6.20196271262,0.5],
[0,39,-1.09245715976,22.1709445502,0.5],
[4,27,11.6313222632,36.6155602654,0.5],
[4,23,4.32163739643,27.9634865851,0.5],
[2,67,8.38628571355,17.3282873753,0.5],
[2,35,4.50715492943,21.1394184895,0.5],
[4,56,10.8700263906,10.0671820189,0.5],
[-0.5,78,10.4908292903,13.8335723835,0.5],
[2,47,6.52672764895,19.0447410054,0.5],
[4,54,19.9914536261,15.263227921,0.5],
[-0.5,31,12.5624317943,17.8082992514,0.5]]

# %%
print("Connection de %s :\n %s"%(address, clientsocket))
# Out:
# Connection de ('172.17.0.2', 54460) :
#  <socket.socket fd=44, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('172.17.0.2', 12010), raddr=('172.17.0.2', 54460)>

# %%
for cycliste in cyclistes:
    time.sleep(1)
    eol     = "\n"
    data    = ["%s"%data for data in cycliste]
    to_send = ";".join(data)+eol
    clientsocket.send(to_send.encode())
# Out:
# ---------------------------------------------------------------------------
# BrokenPipeError                           Traceback (most recent call last)
# <ipython-input-8-e50dcd0cdb02> in <module>
#       4     data    = ["%s"%data for data in cycliste]
#       5     to_send = ";".join(data)+eol
# ----> 6     clientsocket.send(to_send.encode())
#
# BrokenPipeError: [Errno 32] Broken pipe
